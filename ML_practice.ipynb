# %% [markdown]
# <a href="https://colab.research.google.com/github/princeiiitk/Exploratory-Data-Analysis-EDA-/blob/main/ML_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
saidaminsaidaxmadov_chocolate_sales_path = kagglehub.dataset_download('saidaminsaidaxmadov/chocolate-sales')
zahranusratt_student_social_media_addiction_analysis_dataset_path = kagglehub.dataset_download('zahranusratt/student-social-media-addiction-analysis-dataset')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-social-media-addiction-analysis-dataset/Students Social Media Addiction.csv
# /kaggle/input/chocolate-sales/ChocolateSales.pbix
# /kaggle/input/chocolate-sales/Chocolate Sales (2).csv
# /kaggle/input/chocolate-sales/ChocolateSales.pdf
# /kaggle/input/chocolate-sales/ChocolateSales.pbit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/kaggle/input/student-social-media-addiction-analysis-dataset/Students Social Media Addiction.csv')

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Student_ID         Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000  705.000000             705.000000             705.000000
# mean   353.000000   20.659574               4.918723               6.868936
# std    203.660256    1.399217               1.257395               1.126848
# min      1.000000   18.000000               1.500000               3.800000
# 25%    177.000000   19.000000               4.100000               6.000000
# 50%    353.000000   21.000000               4.800000               6.900000
# 75%    529.000000   22.000000               5.800000               7.700000
# max    705.000000   24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# ...

# %%
df.duplicated().count()
# Out:
# np.int64(705)

# %%
df.shape
# Out:
# (705, 13)

# %%
df.drop_duplicates()
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
df.shape
# Out:
# (705, 13)

# %%
df['Relationship_Status'].nunique()
# Out:
# 3

# %%
df.nunique()
# Out:
# Student_ID                      705
# Age                               7
# Gender                            2
# Academic_Level                    3
# Country                         110
# Avg_Daily_Usage_Hours            67
# Most_Used_Platform               12
# Affects_Academic_Performance      2
# Sleep_Hours_Per_Night            59
# Mental_Health_Score               6
# Relationship_Status               3
# Conflicts_Over_Social_Media       6
# Addicted_Score                    8
# dtype: int64

# %%
df['Country'].nunique()
# Out:
# 110

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %%
df.nunique()
# Out:
# Student_ID                      705
# Age                               7
# Gender                            2
# Academic_Level                    3
# Country                         110
# Avg_Daily_Usage_Hours            67
# Most_Used_Platform               12
# Affects_Academic_Performance      2
# Sleep_Hours_Per_Night            59
# Mental_Health_Score               6
# Relationship_Status               3
# Conflicts_Over_Social_Media       6
# Addicted_Score                    8
# dtype: int64

# %%
print(df['Relationship_Status'])
# Out:
# 0      In Relationship
# 1               Single
# 2          Complicated
# 3               Single
# 4      In Relationship
#             ...
# 700    In Relationship
# 701             Single
# 702    In Relationship
# 703             Single
# 704             Single
# Name: Relationship_Status, Length: 705, dtype: object

# %%
df['Relationship_Status'] = df['Relationship_Status'].str.strip()
df['Relationship_Status']=df['Relationship_Status'].map({
    'Single':1,
    'In Relationship':2,
    'Complicated':3
})

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
df.drop(columns=['Country'],inplace=True)

# %%
df['Academic_Level'].nunique()
# Out:
# 3

# %%
df['Academic_Level']=df['Academic_Level'].str.strip().map({
    'High School':1,
    'Graduate':2,
    'Undergraduate':3,

})

# %%
df.head(10)
# Out:
#    Student_ID  Age  Gender  Academic_Level  Avg_Daily_Usage_Hours  \
# 0           1   19  Female               3                    5.2
# 1           2   22    Male               2                    2.1
# 2           3   20  Female               3                    6.0
# 3           4   18    Male               1                    3.0
# 4           5   21    Male               2                    4.5
# 5           6   19  Female               3                    7.2
# 6           7   23    Male               2                    1.5
# 7           8   20  Female               3                    5.8
# 8           9   18    Male               1                    4.0
# 9          10   21  Female               2                    3.3
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# ...

# %%
df['Most_Used_Platform'].unique()
# Out:
# array(['Instagram', 'Twitter', 'TikTok', 'YouTube', 'Facebook',
#        'LinkedIn', 'Snapchat', 'LINE', 'KakaoTalk', 'VKontakte',
#        'WhatsApp', 'WeChat'], dtype=object)

# %%
df.drop(columns=['Most_Used_Platform'],inplace=True)

# %%
df.head(11)
# Out:
#     Student_ID  Age  Gender  Academic_Level  Avg_Daily_Usage_Hours  \
# 0            1   19  Female               3                    5.2
# 1            2   22    Male               2                    2.1
# 2            3   20  Female               3                    6.0
# 3            4   18    Male               1                    3.0
# 4            5   21    Male               2                    4.5
# 5            6   19  Female               3                    7.2
# 6            7   23    Male               2                    1.5
# 7            8   20  Female               3                    5.8
# 8            9   18    Male               1                    4.0
# 9           10   21  Female               2                    3.3
# 10          11   19    Male               3                    4.8
#
#    Affects_Academic_Performance  Sleep_Hours_Per_Night  Mental_Health_Score  \
# 0                           Yes                    6.5                    6
# ...

# %%
col=['Gender','Affects_Academic_Performance']
encode_df=pd.get_dummies(df,columns=col ,drop_first=True,dtype=int)

encode_df.astype(int)
encode_df.head(11)
# Out:
#     Student_ID  Age  Academic_Level  Avg_Daily_Usage_Hours  \
# 0            1   19               3                    5.2
# 1            2   22               2                    2.1
# 2            3   20               3                    6.0
# 3            4   18               1                    3.0
# 4            5   21               2                    4.5
# 5            6   19               3                    7.2
# 6            7   23               2                    1.5
# 7            8   20               3                    5.8
# 8            9   18               1                    4.0
# 9           10   21               2                    3.3
# 10          11   19               3                    4.8
#
#     Sleep_Hours_Per_Night  Mental_Health_Score  Relationship_Status  \
# 0                     6.5                    6                    2
# 1                     7.5                    8                    1
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(encode_df.corr(),annot=True,annot_kws={"size": 10} )
plt.show()

# %%
encode_df.columns
# Out:
# Index(['Student_ID', 'Age', 'Academic_Level', 'Avg_Daily_Usage_Hours',
#        'Sleep_Hours_Per_Night', 'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score', 'Gender_Male',
#        'Affects_Academic_Performance_Yes'],
#       dtype='object')

# %%
col=['Student_ID', 'Academic_Level', 'Avg_Daily_Usage_Hours'
        , 'Relationship_Status',
       'Conflicts_Over_Social_Media', 'Addicted_Score', 'Gender_Male',
       'Affects_Academic_Performance_Yes']
newdf=encode_df.drop(columns=col,axis=1)
newdf.head(11)
# Out:
#     Age  Sleep_Hours_Per_Night  Mental_Health_Score
# 0    19                    6.5                    6
# 1    22                    7.5                    8
# 2    20                    5.0                    5
# 3    18                    7.0                    7
# 4    21                    6.0                    6
# 5    19                    4.5                    4
# 6    23                    8.0                    9
# 7    20                    6.0                    6
# 8    18                    6.5                    7
# 9    21                    7.0                    7
# 10   19                    6.2                    5

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
scale=scale.fit_transform(newdf)
scale
# Out:
# array([[-1.18691539, -0.32763788, -0.20552043],
#        [ 0.95866243,  0.56042327,  1.60562838],
#        [-0.47172278, -1.65972962, -1.11109484],
#        ...,
#        [ 0.24346982, -0.15002565, -0.20552043],
#        [ 2.38904764,  0.56042327,  1.60562838],
#        [-1.18691539, -0.50525011, -1.11109484]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(scale,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=le.predict(X_test)
y_pred
# Out:
# array([7., 6., 6., 8., 5., 6., 7., 7., 8., 7., 8., 8., 6., 6., 7., 5., 7.,
#        6., 7., 7., 7., 7., 7., 4., 8., 8., 5., 5., 6., 6., 6., 6., 6., 8.,
#        7., 8., 6., 5., 6., 6., 7., 4., 4., 5., 7., 8., 5., 5., 7., 7., 6.,
#        5., 6., 6., 5., 5., 5., 5., 8., 6., 5., 7., 6., 5., 8., 8., 6., 6.,
#        6., 7., 4., 7., 7., 7., 5., 8., 7., 6., 8., 4., 7., 6., 8., 5., 7.,
#        6., 5., 5., 7., 8., 7., 7., 7., 8., 4., 5., 8., 6., 5., 8., 5., 8.,
#        6., 7., 7., 6., 5., 7., 8., 8., 5., 5., 7., 6., 7., 6., 5., 6., 7.,
#        7., 6., 5., 7., 5., 4., 6., 4., 5., 7., 7., 8., 6., 5., 5., 7., 6.,
#        7., 6., 5., 5., 5.])

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,y_pred)
print(accuracy)
# Out:
# 1.0
