# %% [markdown]
# <a href="https://colab.research.google.com/github/princeiiitk/Exploratory-Data-Analysis-EDA-/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/EDA(27-01-2026)/patient data(2025).csv')
df.head(11)
# Out:
#           Date       Department  Total Visits  Patient Head Count in OPD  \
# 0   01-01-2025  Anaesthesiology            10                         10
# 1   01-04-2025  Anaesthesiology            14                         14
# 2   01-05-2025  Anaesthesiology            12                         12
# 3   01-07-2025  Anaesthesiology            19                         19
# 4   01-08-2025  Anaesthesiology            10                         10
# 5   01-09-2025  Anaesthesiology             9                          9
# 6   01-10-2025  Anaesthesiology            10                         10
# 7   01-12-2025  Anaesthesiology            13                         13
# 8   02-01-2025  Anaesthesiology             8                          8
# 9   02-04-2025  Anaesthesiology            37                         37
# 10  02-05-2025  Anaesthesiology             7                          7
#
#     ABHA Linked Visits  Total Rx  Rx With ABHA Count  \
# ...

# %%
df.tail()
# Out:
#             Date Department  Total Visits  Patient Head Count in OPD  \
# 7352  30-07-2025    Urology            56                         56
# 7353  31-01-2025    Urology            88                         88
# 7354  31-07-2025    Urology             1                          1
# 7355  31-10-2025    Urology            42                         42
# 7356  31-12-2025    Urology            33                         33
#
#       ABHA Linked Visits  Total Rx  Rx With ABHA Count  \
# 7352                  52         0                   0
# 7353                  83         0                   0
# 7354                   0         0                   0
# 7355                  39         0                   0
# 7356                  30         0                   0
#
#       Linked Rx With ABHA Count  Abha Rx Linked Count On This Day  \
# 7352                          0                                 0
# 7353                          0                                 0
# ...

# %%
df.columns
# Out:
# Index([' Date', ' Department', ' Total Visits', ' Patient Head Count in OPD',
#        ' ABHA Linked Visits', ' Total Rx', ' Rx With ABHA Count',
#        ' Linked Rx With ABHA Count', ' Abha Rx Linked Count On This Day',
#        ' Total Discharge', ' Total Discharge Summary',
#        ' Total Discharge Summary ABHA', ' Discharge Summary Linked Context',
#        ' Discharge Summary Linked Context On This Day'],
#       dtype='object')

# %%
df.shape
# Out:
# (7357, 14)

# %%
df.isnull().sum()
# Out:
# Date                                            0
# Department                                      0
# Total Visits                                    0
# Patient Head Count in OPD                       0
# ABHA Linked Visits                              0
# Total Rx                                        0
# Rx With ABHA Count                              0
# Linked Rx With ABHA Count                       0
# Abha Rx Linked Count On This Day                0
# Total Discharge                                 0
# Total Discharge Summary                         0
# Total Discharge Summary ABHA                    0
# Discharge Summary Linked Context                0
# Discharge Summary Linked Context On This Day    0
# dtype: int64

# %%
df.describe()
# Out:
#        Total Visits  Patient Head Count in OPD  ABHA Linked Visits  \
# count   7357.000000                7357.000000         7357.000000
# mean      57.090798                  56.959223           49.788229
# std       65.176338                  65.060383           60.457894
# min        1.000000                   1.000000            0.000000
# 25%        9.000000                   9.000000            8.000000
# 50%       30.000000                  29.000000           22.000000
# 75%       89.000000                  89.000000           78.000000
# max      362.000000                 356.000000          340.000000
#
#           Total Rx  Rx With ABHA Count  Linked Rx With ABHA Count  \
# count  7357.000000         7357.000000                7357.000000
# mean      3.002447            2.764306                   2.438494
# std      11.031506           10.109900                   8.846367
# min       0.000000            0.000000                   0.000000
# ...

# %%
newdf=df.drop(columns=[' Patient Head Count in OPD',
       ' ABHA Linked Visits',' Rx With ABHA Count',
       ' Linked Rx With ABHA Count', ' Abha Rx Linked Count On This Day',
       ' Total Discharge Summary ABHA', ' Discharge Summary Linked Context',
       ' Discharge Summary Linked Context On This Day'],axis=1)

# %%
newdf.head(10)
# Out:
#          Date       Department  Total Visits  Total Rx  Total Discharge  \
# 0  01-01-2025  Anaesthesiology            10         0                0
# 1  01-04-2025  Anaesthesiology            14         0                0
# 2  01-05-2025  Anaesthesiology            12         0                0
# 3  01-07-2025  Anaesthesiology            19         0                0
# 4  01-08-2025  Anaesthesiology            10         0                0
# 5  01-09-2025  Anaesthesiology             9         4                0
# 6  01-10-2025  Anaesthesiology            10         0                0
# 7  01-12-2025  Anaesthesiology            13         0                0
# 8  02-01-2025  Anaesthesiology             8         0                0
# 9  02-04-2025  Anaesthesiology            37         0                0
#
#    Total Discharge Summary
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...

# %%
newdf['% Rx']=newdf[' Total Rx']/newdf[' Total Visits']*100
newdf['% Rx'] = newdf['% Rx'].replace([np.inf, -np.inf], 0)
newdf.head(10)
# Out:
#          Date       Department   Total Visits   Total Rx   Total Discharge  \
# 0  01-01-2025  Anaesthesiology             10          0                 0
# 1  01-04-2025  Anaesthesiology             14          0                 0
# 2  01-05-2025  Anaesthesiology             12          0                 0
# 3  01-07-2025  Anaesthesiology             19          0                 0
# 4  01-08-2025  Anaesthesiology             10          0                 0
# 5  01-09-2025  Anaesthesiology              9          4                 0
# 6  01-10-2025  Anaesthesiology             10          0                 0
# 7  01-12-2025  Anaesthesiology             13          0                 0
# 8  02-01-2025  Anaesthesiology              8          0                 0
# 9  02-04-2025  Anaesthesiology             37          0                 0
#
#     Total Discharge Summary       % Rx
# 0                         0   0.000000
# 1                         0   0.000000
# ...

# %%
newdf.columns=newdf.columns.str.strip()
newdf.columns
# Out:
# Index(['Date', 'Department', 'Total Visits', 'Total Rx', 'Total Discharge',
#        'Total Discharge Summary', '% Rx'],
#       dtype='object')
